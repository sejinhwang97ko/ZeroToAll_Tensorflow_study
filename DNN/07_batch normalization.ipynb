# %%
# tf.keras.layers.BatchNormalization()

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
import os

# %%
def normalize(train_data, test_data):
    train_data = train_data.astype(np.float32) / 255.0
    test_data = test_data.astype(np.float32) / 255.0

    return train_data, test_data

# %%
def load_mnist():
    (train_data, train_labels), (test_data, test_labels) = mnist.load_data()
    
    # tensorflow가 인풋으로 받은 shape는 [batch_size, height, width, channel]인데
    # mnist의 경우 graysclae image이기 때문에 채널이 1인 것이 생략되어서 3개의 shape
    # 그래서 채널을 하나 더 만들어줘야 함
    train_data = np.expand_dims(train_data, axis=-1) #[N,28,28] -> [N,28,28,1]
    # axis=-1은 여기서 axis=3과 같음. (맨 끝에 채널을 붙여달라는 말이므로)    
    test_data = np.expand_dims(test_data, axis=-1) #[N,28,28] -> [N,28,28,1]
    
    train_data, test_data = normalize(train_data, test_data) # [0~255] -> [0~1]

    # one-hot-encoding
    train_labels = to_categorical(train_labels, 10) #[N,] -> [N,10]
    # label 개수가 10개 이므로 10을 넣음
    test_labels = to_categorical(test_labels, 10) #[N,] -> [N,10]
    return train_data, train_labels, test_data, test_labels

# %%
# shape 펼쳐주기
def flatten():
    return tf.keras.layers.Flatten()

# fully connected layer
def dense(channel, weight_init):
    return tf.keras.layers.Dense(units=channel, use_bias = True,
                                 kernel_initializer=weight_init)
# units=channel : output으로 나가는 채널을 몇개로 설정한 것인지
# use_bias : bias를 사용할 지
# kernel_initialier : weight initializer

def relu():
    return tf.keras.layers.Activation(tf.keras.activations.relu)

def batch_norm():
    return tf.keras.layers.BatchNormalization()

# %%
class create_model(tf.keras.Model):
    def __init__(self, label_dim): # label_dim: 최종적으로 몇 개의 아웃풋을 낼 건지
        super(create_model, self).__init__()
        weight_init = tf.keras.initializers.he_uniform() # HE
        #tf.keras.initializers.glorot_uniform() # Xavier
        
        self.model = tf.keras.Sequential() 
        # convolution이나 fully connected를 층층이 쌓아가는(리스트에 더해주는) 과정
        # list 자료구조 타입
        
        self.model.add(flatten()) # [N,28,28,1] -> [N, 784] # full connected를 할 거기 때문에
        
        # for문 코드 : 총 4층
        for i in range(2):
            # [N,784] -> [N,256] -> [N,256]
            self.model.add(dense(256, weight_init))
            self.model.add(batch_norm())
            self.model.add(relu())
        # layer, norm, activation 순으로 코드를 보통 작성함
        # norm, activation, full connected layer(혹은 convolution layer)) 순도 사용하긴 함
        self.model.add(dense(label_dim,weight_init)) # [N,256] -> [N,10]
    
    def call(self, x, training=None, mask=None):
        x = self.model(x)
        return x

# %%
def loss_fn(model, images, labels):
    logits = model(images, training=True)
    # training=True : dropout 사용하겠다.
    loss = tf.reduce_mean(tf.keras.losses.categorical_crossentropy(y_pred=logits, y_true=labels, 
                                                                   from_logits=True))
    return loss

def accuracy_fn(model, images, labels):
    logits = model(images, training=False)
    # training=True : dropout 사용 안하겠다.
    prediction = tf.equal(tf.argmax(logits,-1), tf.argmax(labels,-1)) #bool
    # 숫자가 큰 값의 위치를 알려달라
    # logits와 labels의 shape는 [batch size, label_dim]인데
    # label_dim 여기서는 10인데 10 중에 가장 큰 값의 위치를 알려달라
    accuracy = tf.reduce_mean(tf.cast(prediction, tf.float32)) # tf.cast: bool > 숫자 형식
    return accuracy

def grad(model, images, labels):
    with tf.GradientTape() as tape:
        loss = loss_fn(model, images, labels)
    return tape.gradient(loss, model.variables)

# %%
train_x, train_y, test_x, test_y = load_mnist()

learning_rate = 0.001
batch_size = 128

training_epochs =1
training_iterations = len(train_x) // batch_size

label_dim = 10

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_x, train_y)).\
    shuffle(buffer_size=100000).\
    prefetch(buffer_size=batch_size).\
    batch(batch_size).\
    repeat()
# shuffle(buffer_size=100000): train_x, train_y가 6만 인데 이것보다 큰 숫자 넣으면 됨
# prefetch(buffer_size=batch_size): 미리 메모리에 batch size 만큼 올려놔라

test_dataset = tf.data.Dataset.from_tensor_slices((test_x, test_y)).\
    shuffle(buffer_size=100000).\
    prefetch(buffer_size=len(test_x)).\
    batch(len(test_x)).\
    repeat()

# %%
train_iterator = tf.compat.v1.data.make_one_shot_iterator(train_dataset)
# train_dataset.make_one_shot_iterator()
test_iterator = tf.compat.v1.data.make_one_shot_iterator(test_dataset)
# test_dataset.make_one_shot_iterator()

network = create_model(label_dim)

optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# %%
""" Writer """
checkpoint_dir = 'checkpoints'
logs_dir = 'logs'

model_dir = 'nn_relu'

def check_folder(dir):
    if not os.path.exists(dir):
        os.makedirs(dir)
    return dir

checkpoint_dir = os.path.join(checkpoint_dir, model_dir)
check_folder(checkpoint_dir)
checkpoint_prefix = os.path.join(checkpoint_dir, model_dir)
logs_dir = os.path.join(logs_dir, model_dir)

# %%
train_flag = True

start_epoch = 0
start_iteration = 0
counter = 0
    
# train phase
checkpoint = tf.train.Checkpoint(dnn=network)
global_step = tf.compat.v1.train.get_or_create_global_step()
# tf.train.create_global_step()
# 각각의 weight가 몇번째 iteration의 weight인지 알려줌

for epoch in range(start_epoch, training_epochs):
    for idx in range(start_iteration, training_iterations):
        train_input, train_label = train_iterator.get_next()
        # image와 label을 받음
        
        grads= grad(network, train_input, train_label)
        optimizer.apply_gradients(grads_and_vars=zip(grads, network.variables),) 
                                  # global_step=global_step)
        
        train_loss = loss_fn(network, train_input, train_label)
        train_accuracy = accuracy_fn(network, train_input, train_label)

        test_input, test_label = test_iterator.get_next()
        test_accuracy = accuracy_fn(network, test_input, test_label)

        print("""Epoch: [%2d] [%5d/%5d],
              train_loss: %.8f,
              train_accuracy: %.4f,
              test_Accuracy: %.4f """\
                % (epoch, idx, training_iterations,
                train_loss, train_accuracy,test_accuracy))
        counter += 1
checkpoint.save(file_prefix=checkpoint_prefix + '-{}'.format(counter))
# Out:
# Epoch: [ 0] [    0/  468],
#               train_loss: 1.99718428,
#               train_accuracy: 0.3516,
#               test_Accuracy: 0.1977
# Epoch: [ 0] [    1/  468],
#               train_loss: 1.96930146,
#               train_accuracy: 0.3828,
#               test_Accuracy: 0.3642
# Epoch: [ 0] [    2/  468],
#               train_loss: 1.76580381,
#               train_accuracy: 0.5156,
#               test_Accuracy: 0.4237
# Epoch: [ 0] [    3/  468],
#               train_loss: 1.81092644,
#               train_accuracy: 0.5078,
#               test_Accuracy: 0.4887
# Epoch: [ 0] [    4/  468],
#               train_loss: 1.55865240,
#               train_accuracy: 0.6406,
#               test_Accuracy: 0.5536
# Epoch: [ 0] [    5/  468],
#               train_loss: 1.53645110,
#               train_accuracy: 0.6250,
#               test_Accuracy: 0.6211
# Epoch: [ 0] [    6/  468],
#               train_loss: 1.36154962,
#               train_accuracy: 0.6641,
#               test_Accuracy: 0.6867
# Epoch: [ 0] [    7/  468],
#               train_loss: 1.21709788,
#               train_accuracy: 0.7344,
#               test_Accuracy: 0.7514
# Epoch: [ 0] [    8/  468],
#               train_loss: 1.03110921,
#               train_accuracy: 0.8281,
#               test_Accuracy: 0.7887
# Epoch: [ 0] [    9/  468],
#               train_loss: 1.02714467,
#               train_accuracy: 0.8203,
#               test_Accuracy: 0.7992
# Epoch: [ 0] [   10/  468],
#               train_loss: 1.08746231,
#               train_accuracy: 0.7422,
#               test_Accuracy: 0.8038
# Epoch: [ 0] [   11/  468],
#               train_loss: 0.88073069,
#               train_accuracy: 0.7344,
#               test_Accuracy: 0.8159
# Epoch: [ 0] [   12/  468],
#               train_loss: 0.75749958,
#               train_accuracy: 0.8359,
#               test_Accuracy: 0.8270
# Epoch: [ 0] [   13/  468],
#               train_loss: 0.63077140,
#               train_accuracy: 0.8359,
#               test_Accuracy: 0.8339
# Epoch: [ 0] [   14/  468],
#               train_loss: 0.61713582,
#               train_accuracy: 0.8359,
#               test_Accuracy: 0.8417
# Epoch: [ 0] [   15/  468],
#               train_loss: 0.61931819,
#               train_accuracy: 0.8516,
#               test_Accuracy: 0.8464
# Epoch: [ 0] [   16/  468],
#               train_loss: 0.56571841,
#               train_accuracy: 0.8359,
#               test_Accuracy: 0.8504
# Epoch: [ 0] [   17/  468],
#               train_loss: 0.50555712,
#               train_accuracy: 0.8438,
#               test_Accuracy: 0.8492
# Epoch: [ 0] [   18/  468],
#               train_loss: 0.48842853,
#               train_accuracy: 0.8438,
#               test_Accuracy: 0.8520
# Epoch: [ 0] [   19/  468],
#               train_loss: 0.46377406,
#               train_accuracy: 0.8828,
#               test_Accuracy: 0.8607
# Epoch: [ 0] [   20/  468],
#               train_loss: 0.59468859,
#               train_accuracy: 0.8516,
#               test_Accuracy: 0.8661
# Epoch: [ 0] [   21/  468],
#               train_loss: 0.52039564,
#               train_accuracy: 0.8516,
#               test_Accuracy: 0.8678
# Epoch: [ 0] [   22/  468],
#               train_loss: 0.35932541,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.8702
# Epoch: [ 0] [   23/  468],
#               train_loss: 0.43602037,
#               train_accuracy: 0.8828,
#               test_Accuracy: 0.8719
# Epoch: [ 0] [   24/  468],
#               train_loss: 0.48735005,
#               train_accuracy: 0.8594,
#               test_Accuracy: 0.8743
# Epoch: [ 0] [   25/  468],
#               train_loss: 0.32964009,
#               train_accuracy: 0.8984,
#               test_Accuracy: 0.8786
# Epoch: [ 0] [   26/  468],
#               train_loss: 0.44485289,
#               train_accuracy: 0.8594,
#               test_Accuracy: 0.8783
# Epoch: [ 0] [   27/  468],
#               train_loss: 0.35764083,
#               train_accuracy: 0.8984,
#               test_Accuracy: 0.8704
# Epoch: [ 0] [   28/  468],
#               train_loss: 0.36465180,
#               train_accuracy: 0.8906,
#               test_Accuracy: 0.8669
# Epoch: [ 0] [   29/  468],
#               train_loss: 0.29056063,
#               train_accuracy: 0.9062,
#               test_Accuracy: 0.8733
# Epoch: [ 0] [   30/  468],
#               train_loss: 0.31257766,
#               train_accuracy: 0.8984,
#               test_Accuracy: 0.8791
# Epoch: [ 0] [   31/  468],
#               train_loss: 0.40715900,
#               train_accuracy: 0.8906,
#               test_Accuracy: 0.8864
# Epoch: [ 0] [   32/  468],
#               train_loss: 0.47883570,
#               train_accuracy: 0.8438,
#               test_Accuracy: 0.8849
# Epoch: [ 0] [   33/  468],
#               train_loss: 0.34220809,
#               train_accuracy: 0.9062,
#               test_Accuracy: 0.8811
# Epoch: [ 0] [   34/  468],
#               train_loss: 0.38484985,
#               train_accuracy: 0.8984,
#               test_Accuracy: 0.8842
# Epoch: [ 0] [   35/  468],
#               train_loss: 0.27193671,
#               train_accuracy: 0.9062,
#               test_Accuracy: 0.8906
# Epoch: [ 0] [   36/  468],
#               train_loss: 0.26446760,
#               train_accuracy: 0.9062,
#               test_Accuracy: 0.8951
# Epoch: [ 0] [   37/  468],
#               train_loss: 0.44433951,
#               train_accuracy: 0.8828,
#               test_Accuracy: 0.8959
# Epoch: [ 0] [   38/  468],
#               train_loss: 0.21880352,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.8911
# Epoch: [ 0] [   39/  468],
#               train_loss: 0.43749559,
#               train_accuracy: 0.8828,
#               test_Accuracy: 0.8839
# Epoch: [ 0] [   40/  468],
#               train_loss: 0.33589903,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.8873
# Epoch: [ 0] [   41/  468],
#               train_loss: 0.33226463,
#               train_accuracy: 0.9062,
#               test_Accuracy: 0.8944
# Epoch: [ 0] [   42/  468],
#               train_loss: 0.43326816,
#               train_accuracy: 0.8594,
#               test_Accuracy: 0.8989
# Epoch: [ 0] [   43/  468],
#               train_loss: 0.36013615,
#               train_accuracy: 0.8516,
#               test_Accuracy: 0.8953
# Epoch: [ 0] [   44/  468],
#               train_loss: 0.44197458,
#               train_accuracy: 0.9062,
#               test_Accuracy: 0.8930
# Epoch: [ 0] [   45/  468],
#               train_loss: 0.38210380,
#               train_accuracy: 0.8828,
#               test_Accuracy: 0.8897
# Epoch: [ 0] [   46/  468],
#               train_loss: 0.34483844,
#               train_accuracy: 0.8984,
#               test_Accuracy: 0.8928
# Epoch: [ 0] [   47/  468],
#               train_loss: 0.27498710,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.8964
# Epoch: [ 0] [   48/  468],
#               train_loss: 0.26369390,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9021
# Epoch: [ 0] [   49/  468],
#               train_loss: 0.29015356,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9032
# Epoch: [ 0] [   50/  468],
#               train_loss: 0.40564817,
#               train_accuracy: 0.8672,
#               test_Accuracy: 0.9031
# Epoch: [ 0] [   51/  468],
#               train_loss: 0.31992459,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.8992
# Epoch: [ 0] [   52/  468],
#               train_loss: 0.30014324,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.8974
# Epoch: [ 0] [   53/  468],
#               train_loss: 0.39125222,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9012
# Epoch: [ 0] [   54/  468],
#               train_loss: 0.35503650,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9045
# Epoch: [ 0] [   55/  468],
#               train_loss: 0.34882438,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9058
# Epoch: [ 0] [   56/  468],
#               train_loss: 0.30865291,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9037
# Epoch: [ 0] [   57/  468],
#               train_loss: 0.36524445,
#               train_accuracy: 0.8672,
#               test_Accuracy: 0.9007
# Epoch: [ 0] [   58/  468],
#               train_loss: 0.33957922,
#               train_accuracy: 0.8984,
#               test_Accuracy: 0.9004
# Epoch: [ 0] [   59/  468],
#               train_loss: 0.29726315,
#               train_accuracy: 0.9062,
#               test_Accuracy: 0.9025
# Epoch: [ 0] [   60/  468],
#               train_loss: 0.34374979,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9053
# Epoch: [ 0] [   61/  468],
#               train_loss: 0.28101045,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9071
# Epoch: [ 0] [   62/  468],
#               train_loss: 0.32617262,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9085
# Epoch: [ 0] [   63/  468],
#               train_loss: 0.36753246,
#               train_accuracy: 0.9062,
#               test_Accuracy: 0.9076
# Epoch: [ 0] [   64/  468],
#               train_loss: 0.27535063,
#               train_accuracy: 0.8984,
#               test_Accuracy: 0.9080
# Epoch: [ 0] [   65/  468],
#               train_loss: 0.27339897,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9110
# Epoch: [ 0] [   66/  468],
#               train_loss: 0.32230628,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9172
# Epoch: [ 0] [   67/  468],
#               train_loss: 0.33931494,
#               train_accuracy: 0.9062,
#               test_Accuracy: 0.9192
# Epoch: [ 0] [   68/  468],
#               train_loss: 0.35804206,
#               train_accuracy: 0.8906,
#               test_Accuracy: 0.9169
# Epoch: [ 0] [   69/  468],
#               train_loss: 0.19921432,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9135
# Epoch: [ 0] [   70/  468],
#               train_loss: 0.39902037,
#               train_accuracy: 0.9062,
#               test_Accuracy: 0.9140
# Epoch: [ 0] [   71/  468],
#               train_loss: 0.31476697,
#               train_accuracy: 0.8984,
#               test_Accuracy: 0.9119
# Epoch: [ 0] [   72/  468],
#               train_loss: 0.34320498,
#               train_accuracy: 0.8906,
#               test_Accuracy: 0.9115
# Epoch: [ 0] [   73/  468],
#               train_loss: 0.21051437,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9110
# Epoch: [ 0] [   74/  468],
#               train_loss: 0.27964354,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9105
# Epoch: [ 0] [   75/  468],
#               train_loss: 0.26428637,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9128
# Epoch: [ 0] [   76/  468],
#               train_loss: 0.22086111,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9158
# Epoch: [ 0] [   77/  468],
#               train_loss: 0.29542744,
#               train_accuracy: 0.8906,
#               test_Accuracy: 0.9203
# Epoch: [ 0] [   78/  468],
#               train_loss: 0.29321271,
#               train_accuracy: 0.8984,
#               test_Accuracy: 0.9192
# Epoch: [ 0] [   79/  468],
#               train_loss: 0.25550637,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9192
# Epoch: [ 0] [   80/  468],
#               train_loss: 0.32894069,
#               train_accuracy: 0.8906,
#               test_Accuracy: 0.9203
# Epoch: [ 0] [   81/  468],
#               train_loss: 0.25538933,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9220
# Epoch: [ 0] [   82/  468],
#               train_loss: 0.27095482,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9213
# Epoch: [ 0] [   83/  468],
#               train_loss: 0.25142747,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9179
# Epoch: [ 0] [   84/  468],
#               train_loss: 0.19745657,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9165
# Epoch: [ 0] [   85/  468],
#               train_loss: 0.22648558,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9174
# Epoch: [ 0] [   86/  468],
#               train_loss: 0.22497262,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9195
# Epoch: [ 0] [   87/  468],
#               train_loss: 0.32963157,
#               train_accuracy: 0.8594,
#               test_Accuracy: 0.9220
# Epoch: [ 0] [   88/  468],
#               train_loss: 0.36062968,
#               train_accuracy: 0.8516,
#               test_Accuracy: 0.9215
# Epoch: [ 0] [   89/  468],
#               train_loss: 0.33173260,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9190
# Epoch: [ 0] [   90/  468],
#               train_loss: 0.39156812,
#               train_accuracy: 0.8906,
#               test_Accuracy: 0.9179
# Epoch: [ 0] [   91/  468],
#               train_loss: 0.23590097,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9152
# Epoch: [ 0] [   92/  468],
#               train_loss: 0.29245517,
#               train_accuracy: 0.8984,
#               test_Accuracy: 0.9152
# Epoch: [ 0] [   93/  468],
#               train_loss: 0.30421919,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9128
# Epoch: [ 0] [   94/  468],
#               train_loss: 0.37463161,
#               train_accuracy: 0.8672,
#               test_Accuracy: 0.9169
# Epoch: [ 0] [   95/  468],
#               train_loss: 0.36627328,
#               train_accuracy: 0.9062,
#               test_Accuracy: 0.9191
# Epoch: [ 0] [   96/  468],
#               train_loss: 0.36422807,
#               train_accuracy: 0.8984,
#               test_Accuracy: 0.9223
# Epoch: [ 0] [   97/  468],
#               train_loss: 0.19455878,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9231
# Epoch: [ 0] [   98/  468],
#               train_loss: 0.32457429,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9262
# Epoch: [ 0] [   99/  468],
#               train_loss: 0.24139391,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9277
# Epoch: [ 0] [  100/  468],
#               train_loss: 0.27188396,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9257
# Epoch: [ 0] [  101/  468],
#               train_loss: 0.32881010,
#               train_accuracy: 0.8984,
#               test_Accuracy: 0.9225
# Epoch: [ 0] [  102/  468],
#               train_loss: 0.18125449,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9194
# Epoch: [ 0] [  103/  468],
#               train_loss: 0.31547385,
#               train_accuracy: 0.9062,
#               test_Accuracy: 0.9180
# Epoch: [ 0] [  104/  468],
#               train_loss: 0.28937101,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9190
# Epoch: [ 0] [  105/  468],
#               train_loss: 0.14788887,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9192
# Epoch: [ 0] [  106/  468],
#               train_loss: 0.19701089,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9214
# Epoch: [ 0] [  107/  468],
#               train_loss: 0.26019526,
#               train_accuracy: 0.9062,
#               test_Accuracy: 0.9241
# Epoch: [ 0] [  108/  468],
#               train_loss: 0.17595544,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9274
# Epoch: [ 0] [  109/  468],
#               train_loss: 0.14238130,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9297
# Epoch: [ 0] [  110/  468],
#               train_loss: 0.23441201,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9293
# Epoch: [ 0] [  111/  468],
#               train_loss: 0.14749038,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9282
# Epoch: [ 0] [  112/  468],
#               train_loss: 0.24333937,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9297
# Epoch: [ 0] [  113/  468],
#               train_loss: 0.29162169,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9287
# Epoch: [ 0] [  114/  468],
#               train_loss: 0.24123731,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9295
# Epoch: [ 0] [  115/  468],
#               train_loss: 0.20906349,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9284
# Epoch: [ 0] [  116/  468],
#               train_loss: 0.24293989,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9265
# Epoch: [ 0] [  117/  468],
#               train_loss: 0.26162425,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9249
# Epoch: [ 0] [  118/  468],
#               train_loss: 0.29907185,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9259
# Epoch: [ 0] [  119/  468],
#               train_loss: 0.23133114,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9260
# Epoch: [ 0] [  120/  468],
#               train_loss: 0.19821976,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9266
# Epoch: [ 0] [  121/  468],
#               train_loss: 0.18521652,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9271
# Epoch: [ 0] [  122/  468],
#               train_loss: 0.11454192,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9273
# Epoch: [ 0] [  123/  468],
#               train_loss: 0.22653061,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9277
# Epoch: [ 0] [  124/  468],
#               train_loss: 0.22007176,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9279
# Epoch: [ 0] [  125/  468],
#               train_loss: 0.16136518,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9275
# Epoch: [ 0] [  126/  468],
#               train_loss: 0.26200289,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9269
# Epoch: [ 0] [  127/  468],
#               train_loss: 0.20009011,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9265
# Epoch: [ 0] [  128/  468],
#               train_loss: 0.14953709,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9275
# Epoch: [ 0] [  129/  468],
#               train_loss: 0.33541360,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9277
# Epoch: [ 0] [  130/  468],
#               train_loss: 0.13937336,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9247
# Epoch: [ 0] [  131/  468],
#               train_loss: 0.16384038,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9257
# Epoch: [ 0] [  132/  468],
#               train_loss: 0.13440649,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9281
# Epoch: [ 0] [  133/  468],
#               train_loss: 0.26701608,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9319
# Epoch: [ 0] [  134/  468],
#               train_loss: 0.33825189,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9335
# Epoch: [ 0] [  135/  468],
#               train_loss: 0.40599421,
#               train_accuracy: 0.9062,
#               test_Accuracy: 0.9340
# Epoch: [ 0] [  136/  468],
#               train_loss: 0.23216674,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9337
# Epoch: [ 0] [  137/  468],
#               train_loss: 0.25650647,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9331
# Epoch: [ 0] [  138/  468],
#               train_loss: 0.20022550,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9367
# Epoch: [ 0] [  139/  468],
#               train_loss: 0.24617650,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9367
# Epoch: [ 0] [  140/  468],
#               train_loss: 0.24761608,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9368
# Epoch: [ 0] [  141/  468],
#               train_loss: 0.20732537,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9378
# Epoch: [ 0] [  142/  468],
#               train_loss: 0.13963655,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9396
# Epoch: [ 0] [  143/  468],
#               train_loss: 0.17935699,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9389
# Epoch: [ 0] [  144/  468],
#               train_loss: 0.14747362,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9386
# Epoch: [ 0] [  145/  468],
#               train_loss: 0.20868981,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9347
# Epoch: [ 0] [  146/  468],
#               train_loss: 0.28901368,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9332
# Epoch: [ 0] [  147/  468],
#               train_loss: 0.20224082,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9348
# Epoch: [ 0] [  148/  468],
#               train_loss: 0.30839586,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9352
# Epoch: [ 0] [  149/  468],
#               train_loss: 0.19938368,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9359
# Epoch: [ 0] [  150/  468],
#               train_loss: 0.18051212,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9346
# Epoch: [ 0] [  151/  468],
#               train_loss: 0.14357716,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9334
# Epoch: [ 0] [  152/  468],
#               train_loss: 0.29712543,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9320
# Epoch: [ 0] [  153/  468],
#               train_loss: 0.28364027,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9326
# Epoch: [ 0] [  154/  468],
#               train_loss: 0.21410401,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9352
# Epoch: [ 0] [  155/  468],
#               train_loss: 0.27153197,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9367
# Epoch: [ 0] [  156/  468],
#               train_loss: 0.29735512,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9380
# Epoch: [ 0] [  157/  468],
#               train_loss: 0.18311591,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9375
# Epoch: [ 0] [  158/  468],
#               train_loss: 0.20101336,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9398
# Epoch: [ 0] [  159/  468],
#               train_loss: 0.21364093,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9382
# Epoch: [ 0] [  160/  468],
#               train_loss: 0.19383821,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9359
# Epoch: [ 0] [  161/  468],
#               train_loss: 0.21465990,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9359
# Epoch: [ 0] [  162/  468],
#               train_loss: 0.23816973,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9370
# Epoch: [ 0] [  163/  468],
#               train_loss: 0.13648835,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9350
# Epoch: [ 0] [  164/  468],
#               train_loss: 0.42943272,
#               train_accuracy: 0.8750,
#               test_Accuracy: 0.9345
# Epoch: [ 0] [  165/  468],
#               train_loss: 0.20485973,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9347
# Epoch: [ 0] [  166/  468],
#               train_loss: 0.20508453,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9359
# Epoch: [ 0] [  167/  468],
#               train_loss: 0.21990295,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9374
# Epoch: [ 0] [  168/  468],
#               train_loss: 0.29049569,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9382
# Epoch: [ 0] [  169/  468],
#               train_loss: 0.21736990,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9375
# Epoch: [ 0] [  170/  468],
#               train_loss: 0.18691339,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9361
# Epoch: [ 0] [  171/  468],
#               train_loss: 0.30450642,
#               train_accuracy: 0.8984,
#               test_Accuracy: 0.9381
# Epoch: [ 0] [  172/  468],
#               train_loss: 0.18237551,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9389
# Epoch: [ 0] [  173/  468],
#               train_loss: 0.22924834,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9394
# Epoch: [ 0] [  174/  468],
#               train_loss: 0.18700887,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9416
# Epoch: [ 0] [  175/  468],
#               train_loss: 0.14263242,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9421
# Epoch: [ 0] [  176/  468],
#               train_loss: 0.18077886,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9431
# Epoch: [ 0] [  177/  468],
#               train_loss: 0.22754048,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9431
# Epoch: [ 0] [  178/  468],
#               train_loss: 0.15402910,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9441
# Epoch: [ 0] [  179/  468],
#               train_loss: 0.10983477,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9452
# Epoch: [ 0] [  180/  468],
#               train_loss: 0.12802073,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9449
# Epoch: [ 0] [  181/  468],
#               train_loss: 0.17946161,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9451
# Epoch: [ 0] [  182/  468],
#               train_loss: 0.22026357,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9446
# Epoch: [ 0] [  183/  468],
#               train_loss: 0.11472879,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9434
# Epoch: [ 0] [  184/  468],
#               train_loss: 0.18567750,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9448
# Epoch: [ 0] [  185/  468],
#               train_loss: 0.18236549,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9462
# Epoch: [ 0] [  186/  468],
#               train_loss: 0.31482658,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9465
# Epoch: [ 0] [  187/  468],
#               train_loss: 0.21320057,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9455
# Epoch: [ 0] [  188/  468],
#               train_loss: 0.13214299,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9425
# Epoch: [ 0] [  189/  468],
#               train_loss: 0.14410137,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9412
# Epoch: [ 0] [  190/  468],
#               train_loss: 0.19737384,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9396
# Epoch: [ 0] [  191/  468],
#               train_loss: 0.18253277,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9375
# Epoch: [ 0] [  192/  468],
#               train_loss: 0.15765779,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9358
# Epoch: [ 0] [  193/  468],
#               train_loss: 0.20955212,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9352
# Epoch: [ 0] [  194/  468],
#               train_loss: 0.21783884,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9367
# Epoch: [ 0] [  195/  468],
#               train_loss: 0.14874868,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9373
# Epoch: [ 0] [  196/  468],
#               train_loss: 0.23176798,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9391
# Epoch: [ 0] [  197/  468],
#               train_loss: 0.18144093,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9379
# Epoch: [ 0] [  198/  468],
#               train_loss: 0.15837187,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9386
# Epoch: [ 0] [  199/  468],
#               train_loss: 0.16025491,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9395
# Epoch: [ 0] [  200/  468],
#               train_loss: 0.23701847,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9434
# Epoch: [ 0] [  201/  468],
#               train_loss: 0.16446938,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9466
# Epoch: [ 0] [  202/  468],
#               train_loss: 0.15960944,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9465
# Epoch: [ 0] [  203/  468],
#               train_loss: 0.21511425,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9445
# Epoch: [ 0] [  204/  468],
#               train_loss: 0.17855868,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9436
# Epoch: [ 0] [  205/  468],
#               train_loss: 0.17148411,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9434
# Epoch: [ 0] [  206/  468],
#               train_loss: 0.11229381,
#               train_accuracy: 0.9844,
#               test_Accuracy: 0.9456
# Epoch: [ 0] [  207/  468],
#               train_loss: 0.27266014,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9462
# Epoch: [ 0] [  208/  468],
#               train_loss: 0.14778964,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9469
# Epoch: [ 0] [  209/  468],
#               train_loss: 0.17325689,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9471
# Epoch: [ 0] [  210/  468],
#               train_loss: 0.16330504,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9468
# Epoch: [ 0] [  211/  468],
#               train_loss: 0.10660169,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9433
# Epoch: [ 0] [  212/  468],
#               train_loss: 0.18228157,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9418
# Epoch: [ 0] [  213/  468],
#               train_loss: 0.17584535,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9409
# Epoch: [ 0] [  214/  468],
#               train_loss: 0.23523507,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9410
# Epoch: [ 0] [  215/  468],
#               train_loss: 0.16012697,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9406
# Epoch: [ 0] [  216/  468],
#               train_loss: 0.23808178,
#               train_accuracy: 0.9141,
#               test_Accuracy: 0.9412
# Epoch: [ 0] [  217/  468],
#               train_loss: 0.17173731,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9456
# Epoch: [ 0] [  218/  468],
#               train_loss: 0.13049088,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9470
# Epoch: [ 0] [  219/  468],
#               train_loss: 0.20023149,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9449
# Epoch: [ 0] [  220/  468],
#               train_loss: 0.20053735,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9440
# Epoch: [ 0] [  221/  468],
#               train_loss: 0.13718922,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9430
# Epoch: [ 0] [  222/  468],
#               train_loss: 0.24047874,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9427
# Epoch: [ 0] [  223/  468],
#               train_loss: 0.29454660,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9452
# Epoch: [ 0] [  224/  468],
#               train_loss: 0.05937108,
#               train_accuracy: 0.9922,
#               test_Accuracy: 0.9470
# Epoch: [ 0] [  225/  468],
#               train_loss: 0.11604397,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9481
# Epoch: [ 0] [  226/  468],
#               train_loss: 0.22254381,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9508
# Epoch: [ 0] [  227/  468],
#               train_loss: 0.20606244,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9521
# Epoch: [ 0] [  228/  468],
#               train_loss: 0.20960940,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9516
# Epoch: [ 0] [  229/  468],
#               train_loss: 0.15298992,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9499
# Epoch: [ 0] [  230/  468],
#               train_loss: 0.19828637,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9495
# Epoch: [ 0] [  231/  468],
#               train_loss: 0.14731008,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9474
# Epoch: [ 0] [  232/  468],
#               train_loss: 0.15220684,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9482
# Epoch: [ 0] [  233/  468],
#               train_loss: 0.16072692,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9484
# Epoch: [ 0] [  234/  468],
#               train_loss: 0.12687939,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9502
# Epoch: [ 0] [  235/  468],
#               train_loss: 0.19304322,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9522
# Epoch: [ 0] [  236/  468],
#               train_loss: 0.16605848,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9514
# Epoch: [ 0] [  237/  468],
#               train_loss: 0.10345414,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9497
# Epoch: [ 0] [  238/  468],
#               train_loss: 0.10954386,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9475
# Epoch: [ 0] [  239/  468],
#               train_loss: 0.11928469,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9464
# Epoch: [ 0] [  240/  468],
#               train_loss: 0.18313915,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9475
# Epoch: [ 0] [  241/  468],
#               train_loss: 0.17752197,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9490
# Epoch: [ 0] [  242/  468],
#               train_loss: 0.21638283,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9521
# Epoch: [ 0] [  243/  468],
#               train_loss: 0.13729110,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9513
# Epoch: [ 0] [  244/  468],
#               train_loss: 0.15611640,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9512
# Epoch: [ 0] [  245/  468],
#               train_loss: 0.16664714,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9516
# Epoch: [ 0] [  246/  468],
#               train_loss: 0.10640661,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9520
# Epoch: [ 0] [  247/  468],
#               train_loss: 0.16549569,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9521
# Epoch: [ 0] [  248/  468],
#               train_loss: 0.12628162,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9520
# Epoch: [ 0] [  249/  468],
#               train_loss: 0.10012037,
#               train_accuracy: 0.9844,
#               test_Accuracy: 0.9525
# Epoch: [ 0] [  250/  468],
#               train_loss: 0.20520642,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9522
# Epoch: [ 0] [  251/  468],
#               train_loss: 0.16387992,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9515
# Epoch: [ 0] [  252/  468],
#               train_loss: 0.12761256,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9511
# Epoch: [ 0] [  253/  468],
#               train_loss: 0.18164067,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9519
# Epoch: [ 0] [  254/  468],
#               train_loss: 0.08229762,
#               train_accuracy: 0.9844,
#               test_Accuracy: 0.9512
# Epoch: [ 0] [  255/  468],
#               train_loss: 0.16797039,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9496
# Epoch: [ 0] [  256/  468],
#               train_loss: 0.06860150,
#               train_accuracy: 0.9844,
#               test_Accuracy: 0.9464
# Epoch: [ 0] [  257/  468],
#               train_loss: 0.11134353,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9453
# Epoch: [ 0] [  258/  468],
#               train_loss: 0.12030450,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9431
# Epoch: [ 0] [  259/  468],
#               train_loss: 0.19057819,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9439
# Epoch: [ 0] [  260/  468],
#               train_loss: 0.09466745,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9456
# Epoch: [ 0] [  261/  468],
#               train_loss: 0.19992681,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9476
# Epoch: [ 0] [  262/  468],
#               train_loss: 0.03915465,
#               train_accuracy: 0.9922,
#               test_Accuracy: 0.9496
# Epoch: [ 0] [  263/  468],
#               train_loss: 0.23783386,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9495
# Epoch: [ 0] [  264/  468],
#               train_loss: 0.15713486,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9505
# Epoch: [ 0] [  265/  468],
#               train_loss: 0.08563014,
#               train_accuracy: 0.9844,
#               test_Accuracy: 0.9513
# Epoch: [ 0] [  266/  468],
#               train_loss: 0.16526292,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9523
# Epoch: [ 0] [  267/  468],
#               train_loss: 0.19641706,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9520
# Epoch: [ 0] [  268/  468],
#               train_loss: 0.09446193,
#               train_accuracy: 0.9844,
#               test_Accuracy: 0.9516
# Epoch: [ 0] [  269/  468],
#               train_loss: 0.12322839,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9522
# Epoch: [ 0] [  270/  468],
#               train_loss: 0.12424368,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9527
# Epoch: [ 0] [  271/  468],
#               train_loss: 0.17541395,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9509
# Epoch: [ 0] [  272/  468],
#               train_loss: 0.13565588,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9503
# Epoch: [ 0] [  273/  468],
#               train_loss: 0.16544485,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9500
# Epoch: [ 0] [  274/  468],
#               train_loss: 0.16013098,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9503
# Epoch: [ 0] [  275/  468],
#               train_loss: 0.08832031,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9502
# Epoch: [ 0] [  276/  468],
#               train_loss: 0.09875566,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9487
# Epoch: [ 0] [  277/  468],
#               train_loss: 0.12574300,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9481
# Epoch: [ 0] [  278/  468],
#               train_loss: 0.13388424,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9464
# Epoch: [ 0] [  279/  468],
#               train_loss: 0.18658514,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9463
# Epoch: [ 0] [  280/  468],
#               train_loss: 0.14293107,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9473
# Epoch: [ 0] [  281/  468],
#               train_loss: 0.10132293,
#               train_accuracy: 0.9844,
#               test_Accuracy: 0.9488
# Epoch: [ 0] [  282/  468],
#               train_loss: 0.14389914,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9504
# Epoch: [ 0] [  283/  468],
#               train_loss: 0.23981556,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9515
# Epoch: [ 0] [  284/  468],
#               train_loss: 0.08073956,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9514
# Epoch: [ 0] [  285/  468],
#               train_loss: 0.25636002,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9512
# Epoch: [ 0] [  286/  468],
#               train_loss: 0.26921684,
#               train_accuracy: 0.8984,
#               test_Accuracy: 0.9500
# Epoch: [ 0] [  287/  468],
#               train_loss: 0.10865208,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9498
# Epoch: [ 0] [  288/  468],
#               train_loss: 0.14559409,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9505
# Epoch: [ 0] [  289/  468],
#               train_loss: 0.24454902,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9513
# Epoch: [ 0] [  290/  468],
#               train_loss: 0.18453041,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9535
# Epoch: [ 0] [  291/  468],
#               train_loss: 0.14431012,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9546
# Epoch: [ 0] [  292/  468],
#               train_loss: 0.20638721,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9552
# Epoch: [ 0] [  293/  468],
#               train_loss: 0.14554892,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9555
# Epoch: [ 0] [  294/  468],
#               train_loss: 0.27101520,
#               train_accuracy: 0.9062,
#               test_Accuracy: 0.9558
# Epoch: [ 0] [  295/  468],
#               train_loss: 0.05556300,
#               train_accuracy: 0.9844,
#               test_Accuracy: 0.9560
# Epoch: [ 0] [  296/  468],
#               train_loss: 0.15198097,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9555
# Epoch: [ 0] [  297/  468],
#               train_loss: 0.10853976,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9539
# Epoch: [ 0] [  298/  468],
#               train_loss: 0.07226373,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9535
# Epoch: [ 0] [  299/  468],
#               train_loss: 0.14433661,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9543
# Epoch: [ 0] [  300/  468],
#               train_loss: 0.05898377,
#               train_accuracy: 0.9922,
#               test_Accuracy: 0.9540
# Epoch: [ 0] [  301/  468],
#               train_loss: 0.14379334,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9552
# Epoch: [ 0] [  302/  468],
#               train_loss: 0.11570612,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9566
# Epoch: [ 0] [  303/  468],
#               train_loss: 0.17001009,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9562
# Epoch: [ 0] [  304/  468],
#               train_loss: 0.10270174,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9553
# Epoch: [ 0] [  305/  468],
#               train_loss: 0.13394113,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9544
# Epoch: [ 0] [  306/  468],
#               train_loss: 0.16278571,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9529
# Epoch: [ 0] [  307/  468],
#               train_loss: 0.10645562,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9511
# Epoch: [ 0] [  308/  468],
#               train_loss: 0.14067608,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9492
# Epoch: [ 0] [  309/  468],
#               train_loss: 0.10106939,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9479
# Epoch: [ 0] [  310/  468],
#               train_loss: 0.12789656,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9480
# Epoch: [ 0] [  311/  468],
#               train_loss: 0.14794397,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9474
# Epoch: [ 0] [  312/  468],
#               train_loss: 0.12790206,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9461
# Epoch: [ 0] [  313/  468],
#               train_loss: 0.15087932,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9464
# Epoch: [ 0] [  314/  468],
#               train_loss: 0.13009053,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9484
# Epoch: [ 0] [  315/  468],
#               train_loss: 0.23135965,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9515
# Epoch: [ 0] [  316/  468],
#               train_loss: 0.07881478,
#               train_accuracy: 0.9844,
#               test_Accuracy: 0.9530
# Epoch: [ 0] [  317/  468],
#               train_loss: 0.21538456,
#               train_accuracy: 0.9219,
#               test_Accuracy: 0.9568
# Epoch: [ 0] [  318/  468],
#               train_loss: 0.10674474,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9572
# Epoch: [ 0] [  319/  468],
#               train_loss: 0.18797892,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9578
# Epoch: [ 0] [  320/  468],
#               train_loss: 0.17214788,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9550
# Epoch: [ 0] [  321/  468],
#               train_loss: 0.12666532,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9519
# Epoch: [ 0] [  322/  468],
#               train_loss: 0.18267155,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9486
# Epoch: [ 0] [  323/  468],
#               train_loss: 0.08918316,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9455
# Epoch: [ 0] [  324/  468],
#               train_loss: 0.10458614,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9486
# Epoch: [ 0] [  325/  468],
#               train_loss: 0.22300839,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9505
# Epoch: [ 0] [  326/  468],
#               train_loss: 0.13735789,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9517
# Epoch: [ 0] [  327/  468],
#               train_loss: 0.10697272,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9527
# Epoch: [ 0] [  328/  468],
#               train_loss: 0.16448437,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9533
# Epoch: [ 0] [  329/  468],
#               train_loss: 0.19471554,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9523
# Epoch: [ 0] [  330/  468],
#               train_loss: 0.14859810,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9511
# Epoch: [ 0] [  331/  468],
#               train_loss: 0.20999621,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9515
# Epoch: [ 0] [  332/  468],
#               train_loss: 0.15808097,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9533
# Epoch: [ 0] [  333/  468],
#               train_loss: 0.15769283,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9546
# Epoch: [ 0] [  334/  468],
#               train_loss: 0.06591197,
#               train_accuracy: 0.9922,
#               test_Accuracy: 0.9545
# Epoch: [ 0] [  335/  468],
#               train_loss: 0.11119464,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9530
# Epoch: [ 0] [  336/  468],
#               train_loss: 0.09380846,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9502
# Epoch: [ 0] [  337/  468],
#               train_loss: 0.25910962,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9490
# Epoch: [ 0] [  338/  468],
#               train_loss: 0.17639092,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9522
# Epoch: [ 0] [  339/  468],
#               train_loss: 0.22495627,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9541
# Epoch: [ 0] [  340/  468],
#               train_loss: 0.15362252,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9546
# Epoch: [ 0] [  341/  468],
#               train_loss: 0.18770680,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9562
# Epoch: [ 0] [  342/  468],
#               train_loss: 0.15391336,
#               train_accuracy: 0.9453,
# ...
# Epoch: [ 0] [  354/  468],
#               train_loss: 0.16439600,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9504
# Epoch: [ 0] [  355/  468],
#               train_loss: 0.18231857,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9533
# Epoch: [ 0] [  356/  468],
#               train_loss: 0.07680643,
#               train_accuracy: 0.9844,
#               test_Accuracy: 0.9517
# Epoch: [ 0] [  357/  468],
#               train_loss: 0.17331155,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9505
# Epoch: [ 0] [  358/  468],
#               train_loss: 0.12610173,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9492
# Epoch: [ 0] [  359/  468],
#               train_loss: 0.09885032,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9489
# Epoch: [ 0] [  360/  468],
#               train_loss: 0.18783620,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9489
# Epoch: [ 0] [  361/  468],
#               train_loss: 0.10723501,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9494
# Epoch: [ 0] [  362/  468],
#               train_loss: 0.13952732,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9502
# Epoch: [ 0] [  363/  468],
#               train_loss: 0.15560210,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9509
# Epoch: [ 0] [  364/  468],
#               train_loss: 0.14620350,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9520
# Epoch: [ 0] [  365/  468],
#               train_loss: 0.16191074,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9547
# Epoch: [ 0] [  366/  468],
#               train_loss: 0.09546073,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9573
# Epoch: [ 0] [  367/  468],
#               train_loss: 0.11416072,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9600
# Epoch: [ 0] [  368/  468],
#               train_loss: 0.09809041,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9623
# Epoch: [ 0] [  369/  468],
#               train_loss: 0.11543422,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9628
# Epoch: [ 0] [  370/  468],
#               train_loss: 0.19270293,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9618
# Epoch: [ 0] [  371/  468],
#               train_loss: 0.11511476,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9605
# Epoch: [ 0] [  372/  468],
#               train_loss: 0.11960702,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9595
# Epoch: [ 0] [  373/  468],
#               train_loss: 0.13520068,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9591
# Epoch: [ 0] [  374/  468],
#               train_loss: 0.10802236,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9575
# Epoch: [ 0] [  375/  468],
#               train_loss: 0.17254874,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9586
# Epoch: [ 0] [  376/  468],
#               train_loss: 0.13733016,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9594
# Epoch: [ 0] [  377/  468],
#               train_loss: 0.10361508,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9595
# Epoch: [ 0] [  378/  468],
#               train_loss: 0.06930275,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9608
# Epoch: [ 0] [  379/  468],
#               train_loss: 0.16694795,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9612
# Epoch: [ 0] [  380/  468],
#               train_loss: 0.08952817,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9611
# Epoch: [ 0] [  381/  468],
#               train_loss: 0.19652770,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9618
# Epoch: [ 0] [  382/  468],
#               train_loss: 0.10967438,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9608
# Epoch: [ 0] [  383/  468],
#               train_loss: 0.11442034,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9597
# Epoch: [ 0] [  384/  468],
#               train_loss: 0.11025327,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9598
# Epoch: [ 0] [  385/  468],
#               train_loss: 0.06987307,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9595
# Epoch: [ 0] [  386/  468],
#               train_loss: 0.16532342,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9598
# Epoch: [ 0] [  387/  468],
#               train_loss: 0.13667218,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9581
# Epoch: [ 0] [  388/  468],
#               train_loss: 0.15462267,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9583
# Epoch: [ 0] [  389/  468],
#               train_loss: 0.16659422,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9600
# Epoch: [ 0] [  390/  468],
#               train_loss: 0.12112961,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9605
# Epoch: [ 0] [  391/  468],
#               train_loss: 0.13823429,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9606
# Epoch: [ 0] [  392/  468],
#               train_loss: 0.13756917,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9570
# Epoch: [ 0] [  393/  468],
#               train_loss: 0.06792904,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9533
# Epoch: [ 0] [  394/  468],
#               train_loss: 0.13118859,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9509
# Epoch: [ 0] [  395/  468],
#               train_loss: 0.14242849,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9519
# Epoch: [ 0] [  396/  468],
#               train_loss: 0.06607527,
#               train_accuracy: 0.9844,
#               test_Accuracy: 0.9549
# Epoch: [ 0] [  397/  468],
#               train_loss: 0.08760004,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9596
# Epoch: [ 0] [  398/  468],
#               train_loss: 0.11890154,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9636
# Epoch: [ 0] [  399/  468],
#               train_loss: 0.09437069,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9644
# Epoch: [ 0] [  400/  468],
#               train_loss: 0.15018651,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9627
# Epoch: [ 0] [  401/  468],
#               train_loss: 0.09812173,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9609
# Epoch: [ 0] [  402/  468],
#               train_loss: 0.12899077,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9597
# Epoch: [ 0] [  403/  468],
#               train_loss: 0.15168622,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9588
# Epoch: [ 0] [  404/  468],
#               train_loss: 0.09267337,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9591
# Epoch: [ 0] [  405/  468],
#               train_loss: 0.07321106,
#               train_accuracy: 0.9844,
#               test_Accuracy: 0.9602
# Epoch: [ 0] [  406/  468],
#               train_loss: 0.15639704,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9623
# Epoch: [ 0] [  407/  468],
#               train_loss: 0.10873634,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9622
# Epoch: [ 0] [  408/  468],
#               train_loss: 0.17778794,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9621
# Epoch: [ 0] [  409/  468],
#               train_loss: 0.12687480,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9604
# Epoch: [ 0] [  410/  468],
#               train_loss: 0.11359309,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9599
# Epoch: [ 0] [  411/  468],
#               train_loss: 0.13876140,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9591
# Epoch: [ 0] [  412/  468],
#               train_loss: 0.09922283,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9582
# Epoch: [ 0] [  413/  468],
#               train_loss: 0.08954933,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9575
# Epoch: [ 0] [  414/  468],
#               train_loss: 0.15214714,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9592
# Epoch: [ 0] [  415/  468],
#               train_loss: 0.16307470,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9595
# Epoch: [ 0] [  416/  468],
#               train_loss: 0.12738000,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9616
# Epoch: [ 0] [  417/  468],
#               train_loss: 0.16970503,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9635
# Epoch: [ 0] [  418/  468],
#               train_loss: 0.15827301,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9641
# Epoch: [ 0] [  419/  468],
#               train_loss: 0.04536677,
#               train_accuracy: 1.0000,
#               test_Accuracy: 0.9636
# Epoch: [ 0] [  420/  468],
#               train_loss: 0.17330214,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9632
# Epoch: [ 0] [  421/  468],
#               train_loss: 0.07425525,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9604
# Epoch: [ 0] [  422/  468],
#               train_loss: 0.17775288,
#               train_accuracy: 0.9375,
#               test_Accuracy: 0.9600
# Epoch: [ 0] [  423/  468],
#               train_loss: 0.16794609,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9609
# Epoch: [ 0] [  424/  468],
#               train_loss: 0.15597455,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9630
# Epoch: [ 0] [  425/  468],
#               train_loss: 0.12851045,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9641
# Epoch: [ 0] [  426/  468],
#               train_loss: 0.12366986,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9652
# Epoch: [ 0] [  427/  468],
#               train_loss: 0.07204165,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9650
# Epoch: [ 0] [  428/  468],
#               train_loss: 0.10087813,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9657
# Epoch: [ 0] [  429/  468],
#               train_loss: 0.11085439,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9660
# Epoch: [ 0] [  430/  468],
#               train_loss: 0.10603597,
#               train_accuracy: 0.9844,
#               test_Accuracy: 0.9668
# Epoch: [ 0] [  431/  468],
#               train_loss: 0.11278757,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9664
# Epoch: [ 0] [  432/  468],
#               train_loss: 0.07012814,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9662
# Epoch: [ 0] [  433/  468],
#               train_loss: 0.03887068,
#               train_accuracy: 0.9922,
#               test_Accuracy: 0.9665
# Epoch: [ 0] [  434/  468],
#               train_loss: 0.06693375,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9667
# Epoch: [ 0] [  435/  468],
#               train_loss: 0.15082748,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9666
# Epoch: [ 0] [  436/  468],
#               train_loss: 0.05130654,
#               train_accuracy: 0.9844,
#               test_Accuracy: 0.9666
# Epoch: [ 0] [  437/  468],
#               train_loss: 0.17349684,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9664
# Epoch: [ 0] [  438/  468],
#               train_loss: 0.17310104,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9665
# Epoch: [ 0] [  439/  468],
#               train_loss: 0.07555279,
#               train_accuracy: 0.9844,
#               test_Accuracy: 0.9667
# Epoch: [ 0] [  440/  468],
#               train_loss: 0.14745438,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9664
# Epoch: [ 0] [  441/  468],
#               train_loss: 0.13888693,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9657
# Epoch: [ 0] [  442/  468],
#               train_loss: 0.13977125,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9648
# Epoch: [ 0] [  443/  468],
#               train_loss: 0.08032905,
#               train_accuracy: 0.9844,
#               test_Accuracy: 0.9635
# Epoch: [ 0] [  444/  468],
#               train_loss: 0.09428222,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9632
# Epoch: [ 0] [  445/  468],
#               train_loss: 0.09225596,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9632
# Epoch: [ 0] [  446/  468],
#               train_loss: 0.15730543,
#               train_accuracy: 0.9453,
#               test_Accuracy: 0.9639
# Epoch: [ 0] [  447/  468],
#               train_loss: 0.16414678,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9651
# Epoch: [ 0] [  448/  468],
#               train_loss: 0.03084409,
#               train_accuracy: 1.0000,
#               test_Accuracy: 0.9659
# Epoch: [ 0] [  449/  468],
#               train_loss: 0.14147253,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9666
# Epoch: [ 0] [  450/  468],
#               train_loss: 0.23264733,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9662
# Epoch: [ 0] [  451/  468],
#               train_loss: 0.07398051,
#               train_accuracy: 0.9766,
#               test_Accuracy: 0.9645
# Epoch: [ 0] [  452/  468],
#               train_loss: 0.04563791,
#               train_accuracy: 0.9844,
#               test_Accuracy: 0.9632
# Epoch: [ 0] [  453/  468],
#               train_loss: 0.21254042,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9626
# Epoch: [ 0] [  454/  468],
#               train_loss: 0.09979093,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9636
# Epoch: [ 0] [  455/  468],
#               train_loss: 0.08999163,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9631
# Epoch: [ 0] [  456/  468],
#               train_loss: 0.08960573,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9636
# Epoch: [ 0] [  457/  468],
#               train_loss: 0.11096193,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9649
# Epoch: [ 0] [  458/  468],
#               train_loss: 0.09091017,
#               train_accuracy: 0.9844,
#               test_Accuracy: 0.9645
# Epoch: [ 0] [  459/  468],
#               train_loss: 0.14700350,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9651
# Epoch: [ 0] [  460/  468],
#               train_loss: 0.06557839,
#               train_accuracy: 0.9844,
#               test_Accuracy: 0.9648
# Epoch: [ 0] [  461/  468],
#               train_loss: 0.11300411,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9655
# Epoch: [ 0] [  462/  468],
#               train_loss: 0.10900708,
#               train_accuracy: 0.9531,
#               test_Accuracy: 0.9651
# Epoch: [ 0] [  463/  468],
#               train_loss: 0.08735105,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9635
# Epoch: [ 0] [  464/  468],
#               train_loss: 0.18441117,
#               train_accuracy: 0.9609,
#               test_Accuracy: 0.9629
# Epoch: [ 0] [  465/  468],
#               train_loss: 0.20035802,
#               train_accuracy: 0.9297,
#               test_Accuracy: 0.9643
# Epoch: [ 0] [  466/  468],
#               train_loss: 0.08519102,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9643
# Epoch: [ 0] [  467/  468],
#               train_loss: 0.10716657,
#               train_accuracy: 0.9688,
#               test_Accuracy: 0.9648
# 'checkpoints\\nn_relu\\nn_relu-468-1'
